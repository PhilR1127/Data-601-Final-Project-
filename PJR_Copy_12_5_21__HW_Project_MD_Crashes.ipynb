# %% [markdown]
# ## Dataset Resources
#
# [Vehicle Crashes](https://opendata.maryland.gov/Public-Safety/Maryland-Statewide-Vehicle-Crashes/65du-s3qu)
#
# [Personal Details](https://opendata.maryland.gov/Public-Safety/Maryland-Statewide-Vehicle-Crashes-Person-Details-/py4c-dicf)
#
# [Vehicle Details](https://opendata.maryland.gov/Public-Safety/Maryland-Statewide-Vehicle-Crashes-Vehicle-Details/mhft-5t5y)

# %% [markdown]
# ## Homework Details
#
# The objective: tell a data story about the vehicle crashes that happened in 2020 and 2021, through a combination of both narrative text and data exploration. A “story” could be defined any number of ways, and that’s deliberate. The challenge is to deeply explore (through data) the causes, identifications or patterns of a specific group/subgroup of accidents. That group can be defined in the macro (for example: any accidents that is reported as 'Property Damage Crash') or the micro (for example: the results of the accidents happened on 'CAPITAL BELTWAY' at a certain time with certain safety equipments were put-on or not. ). This is an opportunity to be creative and tell the story of a very important phenomenon for both individual level and governance level.
#
# __Grading Criterias__
#
# __Composition:__ Is there a clear narrative thread to the story that’s articulated and supported by data? The subject should be well defined, well researched, and well supported through the use of data and visualizations.
#
# __Originality:__ Does the reader learn something new through this submission? Or is the reader challenged to think about something in a new way? A great entry will be informative, thought provoking, and fresh all at the same time.
#
# __Documentation:__ Are your code, and notebook, and additional data sources well documented so a reader can understand what you did? Are your sources clearly cited? A high quality analysis should be concise and clear at each step so the rationale is easy to follow and the process is reproducible

# %%
import pandas as pd

# %%
from google.colab import files
upload = files.upload()
# Out:
#      <input type="file" id="files-dee20cba-81ac-4ad6-bf36-73366d888f3e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-dee20cba-81ac-4ad6-bf36-73366d888f3e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>

# %%
vcrashes=pd.read_csv('Maryland_Statewide_Vehicle_Crashes.csv')
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (34,46) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
peoplecrashes = pd.read_csv('/content/Maryland_Statewide_Vehicle_Crashes_-_Person_Details__Anonymized_ (1).csv')
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (37) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
vcrashesdetails=pd.read_csv('/content/Maryland_Statewide_Vehicle_Crashes_-_Vehicle_Details.csv')

# %%
vcrashes.head()
# Out:
#    YEAR QUARTER  ...  LONGITUDE                                    LOCATION
# 0  2020      Q2  ... -76.503693             POINT (-76.5036932 39.27726285)
# 1  2020      Q2  ... -76.616429    POINT (-76.616429453205 39.311024794431)
# 2  2020      Q2  ... -77.193413    POINT (-77.193412729561 39.140680249069)
# 3  2017      Q2  ... -76.635215  POINT (-76.6352150952347 39.2829284750108)
# 4  2020      Q2  ... -75.951314          POINT (-75.951314 39.611027833333)
#
# [5 rows x 56 columns]

# %%
vcrashes.tail()
# Out:
#         YEAR QUARTER  ...  LONGITUDE                                  LOCATION
# 742920  2021      Q3  ... -76.785800  POINT (-76.785800279346 39.356336033404)
# 742921  2021      Q3  ... -76.875250       POINT (-76.875250416667 38.6665204)
# 742922  2021      Q3  ... -76.561917  POINT (-76.561916515491 38.568446124487)
# 742923  2021      Q3  ... -76.870448  POINT (-76.870448144383 39.127955739008)
# 742924  2021      Q3  ... -77.043965       POINT (-77.0439649 38.549356666667)
#
# [5 rows x 56 columns]

# %%
vcrashes.shape
# Out:
# (742925, 56)

# %%
vcrashes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 742925 entries, 0 to 742924
# Data columns (total 56 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   YEAR                   742925 non-null  int64
#  1   QUARTER                742925 non-null  object
#  2   LIGHT_DESC             715309 non-null  object
#  3   LIGHT_CODE             742925 non-null  float64
#  4   COUNTY_DESC            742917 non-null  object
#  5   COUNTY_NO              742917 non-null  float64
#  6   MUNI_DESC              0 non-null       float64
#  7   MUNI_CODE              551361 non-null  float64
#  8   JUNCTION_DESC          643419 non-null  object
#  9   JUNCTION_CODE          668268 non-null  float64
#  10  COLLISION_TYPE_DESC    742925 non-null  object
#  11  COLLISION_TYPE_CODE    742925 non-null  int64
#  12  SURF_COND_DESC         666108 non-null  object
#  13  SURF_COND_CODE         668268 non-null  float64
# ...

# %%
peoplecrashes.head()
# Out:
#   SEX_DESC SEX_CODE     CONDITION_DESC  ...  AIRBAG_DEPLOYED  YEAR  Quarter
# 0   Female        F  Apparently Normal  ...              0.0  2017       Q2
# 1     Male        M                NaN  ...              1.0  2017       Q2
# 2   Female        F                NaN  ...              1.0  2016       Q2
# 3     Male        M                NaN  ...              1.0  2018       Q3
# 4   Female        F  Apparently Normal  ...              NaN  2015       Q2
#
# [5 rows x 48 columns]

# %%
peoplecrashes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1664889 entries, 0 to 1664888
# Data columns (total 48 columns):
#  #   Column                 Non-Null Count    Dtype
# ---  ------                 --------------    -----
#  0   SEX_DESC               1538750 non-null  object
#  1   SEX_CODE               1538750 non-null  object
#  2   CONDITION_DESC         1269833 non-null  object
#  3   CONDITION_CODE         1272926 non-null  float64
#  4   INJ_SEVER_DESC         1664889 non-null  object
#  5   INJ_SEVER_CODE         1664889 non-null  int64
#  6   REPORT_NO              1664889 non-null  object
#  7   OCC_SEAT_POS_DESC      387726 non-null   object
#  8   OCC_SEAT_POS_CODE      387726 non-null   float64
#  9   PED_VISIBLE_DESC       30217 non-null    object
#  10  PED_VISIBLE_CODE       30217 non-null    float64
#  11  PED_OBEY_DESC          30217 non-null    object
#  12  PED_OBEY_CODE          30217 non-null    float64
#  13  PED_TYPE_DESC          30217 non-null    object
# ...

# %%
peoplecrashes.tail()
# Out:
#         SEX_DESC SEX_CODE     CONDITION_DESC  ...  AIRBAG_DEPLOYED  YEAR  Quarter
# 1664884   Female        F  Apparently Normal  ...              1.0  2021       Q3
# 1664885      NaN      NaN            Unknown  ...              0.0  2021       Q3
# 1664886     Male        M  Apparently Normal  ...              1.0  2021       Q3
# 1664887      NaN      NaN            Unknown  ...              1.0  2021       Q3
# 1664888     Male        M  Apparently Normal  ...              1.0  2021       Q3
#
# [5 rows x 48 columns]

# %%
peoplecrashes.shape
# Out:
# (1664889, 48)

# %%
vcrashes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 742925 entries, 0 to 742924
# Data columns (total 56 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   YEAR                   742925 non-null  int64
#  1   QUARTER                742925 non-null  object
#  2   LIGHT_DESC             715309 non-null  object
#  3   LIGHT_CODE             742925 non-null  float64
#  4   COUNTY_DESC            742917 non-null  object
#  5   COUNTY_NO              742917 non-null  float64
#  6   MUNI_DESC              0 non-null       float64
#  7   MUNI_CODE              551361 non-null  float64
#  8   JUNCTION_DESC          643419 non-null  object
#  9   JUNCTION_CODE          668268 non-null  float64
#  10  COLLISION_TYPE_DESC    742925 non-null  object
#  11  COLLISION_TYPE_CODE    742925 non-null  int64
#  12  SURF_COND_DESC         666108 non-null  object
#  13  SURF_COND_CODE         668268 non-null  float64
# ...

# %%
vcrashesdetails.head()
# Out:
#   HARM_EVENT_DESC  HARM_EVENT_CODE  ...  YEAR Quarter
# 0   Other Vehicle              1.0  ...  2020      Q2
# 1   Other Vehicle              1.0  ...  2020      Q2
# 2   Other Vehicle              1.0  ...  2020      Q2
# 3    Fixed Object              9.0  ...  2020      Q2
# 4   Other Vehicle              1.0  ...  2020      Q2
#
# [5 rows x 49 columns]

# %%
vcrashesdetails.shape
# Out:
# (1386222, 49)

# %%
crashes_people_vdetails=pd.merge(peoplecrashes,vcrashesdetails)

# %%
crashes_people_vdetails.head()
# Out:
# Empty DataFrame
# ...

# %%
merged1=pd.merge(vcrashes,vcrashesdetails)

# %%
merged1.head()
# Out:
#    YEAR QUARTER  ... AREA_DAMAGED_CODE_MAIN  Quarter
# 0  2020      Q2  ...                    8.0       Q2
# 1  2020      Q2  ...                    1.0       Q2
# 2  2020      Q2  ...                   12.0       Q2
# 3  2020      Q2  ...                   12.0       Q2
# 4  2020      Q2  ...                   12.0       Q2
#
# [5 rows x 103 columns]

# %%
merged1.shape
# Out:
# (1386184, 103)

# %%
merged_all = pd.merge(merged1,peoplecrashes, on='REPORT_NO', how = 'outer', suffixes=['_merged1','_peoplecrashes'])

# %%
merged_all.shape

# %%
merged_all.info(10)

# %%
### Get ages of drivers: first transform column to string 
##merged_all['DATE_OF_BIRTH']=merged_all['DATE_OF_BIRTH'].astype('str')
## then create datetime object for birthdates
##merged_all['birthdates']=pd.to_datetime(merged_all['DATE_OF_BIRTH'], format = '%Y%m%d')
##merged_all.info()

## create driver year of birth in datetime
## merged_all['year_of_birth'] = (merged_all['birthdates']).dt.year

###check value counts 
### merged_all['birthdates'].value_counts()

###create accident_date column and convert accident date into year of the crash
###Create the accident_date column just like in HW#3, then: 
###merged_all['year_of_crash'] = (merged_all['accident_date']).dt.year

###Then create new column 'age of driver'
### merged_all['age_of_driver'] = merged_all['year_of_crash'] - merged_all['year_of_birth'] 
###look at groupby scenarios using ['year_of_birth']

# %% [markdown]
# # Deliverables

# %% [markdown]
# ## Phase-I:
#
# __Due to 11/26/2021 (Friday) by 23:59pm__
#
# 1. Form your teams and fill-out this form: [Phase-I Check Point](https://forms.gle/Dyko5cfLt5RVYjo49)
#
# 2. If a team wants to use another dataset then they should explain clearly why and how by 11/25/2021 7:10pm.

# %% [markdown]
# # Phase - II
#
# __Due to 12/06/2021 (Monday) by 23:59 pm__
#
# 1. Report: Submit a one-page (maximum) PDF describing what have you accomplished in this project so far.
# 2. In that report, describe clearly each team member's contribution and their future responsibility.
# 3. Describe clearly the plan for the next steps.

# %% [markdown]
# # Final Phase and Submitting Your Work
#
# __Due to 12/19/2021 (Sunday) by 23:59 pm__
#
# - Each group should submit a maximum one page summary report.
#
# - Submit a video recording with your teams presentation. Each member should have 5-10 minutes of talking time.
#
# - Each group will submit a jupyter notebook that contains narration and the visualizations that supports the 'story'.

# %% [markdown]
# ## Musts and Must nots

# %% [markdown]
# 1. When I restart the `runtime` each cell in your notebook should run without any errors. If I encounter with an error than I will reach out to you and allow you to fix the error but you will loose 20 pts out of 100 pts.
#
# 2. You should definitely merge the datasets and use most of the data provided to you. In the case, your work uses the data coming from only one dataset then you will loose 20 pts up-front.
#
# 3. In the notebook you submit, you should clearly explain why you choose to inclde that particular cell. If the cell is outputting a visualization then in a text-cell explain why you choose to add that visualization. For each cell that is not directly/logically relevant to your story, you will loose pts.
#
# 4. If you are using a code that is taken from some other sources then add a reference. If all of your code is taken from some other resources then what is your contribution? As we talk about this in the class, it is not worthed to deal with academic misconduct claims so please be careful about this.

# %% [markdown]
# # Examples
#
# [Brexit](https://news.sky.com/story/better-for-brexit-how-uk-has-changed-since-leave-vote-11920143)
#
# [Uncertainty in Forest Products Market](https://insights.risiinfo.com/ufpm-report-2020/index.html)
#
# [Kaggle - From the Kaggle Survey Competition](https://www.kaggle.com/andradaolteanu/how-are-the-ladies-and-the-gents-doing)
