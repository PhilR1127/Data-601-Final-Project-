# %% [markdown]
# <a href="https://colab.research.google.com/github/PhilR1127/Data-601-Final-Project-/blob/main/10_26_99_Data_699_Copy_of_BigQuery_bquxjob_484f3fef_18b6da3ab4c.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# @title Setup
from google.colab import auth
from google.cloud import bigquery
from google.colab import data_table

project = 'data-699' # Project ID inserted based on the query results selected to explore
location = 'US' # Location inserted based on the query results selected to explore
client = bigquery.Client(project=project, location=location)
data_table.enable_dataframe_formatter()
auth.authenticate_user()

# %% [markdown]
# ## Reference SQL syntax from the original job
# Use the ```jobs.query```
# [method](https://cloud.google.com/bigquery/docs/reference/rest/v2/jobs/query) to
# return the SQL syntax from the job. This can be copied from the output cell
# below to edit the query now or in the future. Alternatively, you can use
# [this link](https://console.cloud.google.com/bigquery?j=data-699:US:bquxjob_484f3fef_18b6da3ab4c)
# back to BigQuery to edit the query within the BigQuery user interface.

# %%
# Running this code will display the query used to generate your previous job

job = client.get_job('bquxjob_484f3fef_18b6da3ab4c') # Job ID inserted based on the query results selected to explore
print(job.query)
# Out:
# SELECT subject_id, AGE_patient, AVG_HR, AVG_SBP,AVG_DBP,AVG_O2SAT,atime,dtime,inptdeath,Date_of_Death FROM `data-699.12345.Patients_Admissions_ER Vitals`

# %% [markdown]
# # Result set loaded from BigQuery job as a DataFrame
# Query results are referenced from the Job ID ran from BigQuery and the query
# does not need to be re-run to explore results. The ```to_dataframe```
# [method](https://googleapis.dev/python/bigquery/latest/generated/google.cloud.bigquery.job.QueryJob.html#google.cloud.bigquery.job.QueryJob.to_dataframe)
# downloads the results to a Pandas DataFrame by using the BigQuery Storage API.
#
# To edit query syntax, you can do so from the BigQuery SQL editor or in the
# ```Optional:``` sections below.

# %%
# Running this code will read results from your previous job

job = client.get_job('bquxjob_484f3fef_18b6da3ab4c') # Job ID inserted based on the query results selected to explore
results = job.to_dataframe()
results
# Out:
# ...
#         subject_id  AGE_patient         AVG_HR     AVG_SBP    AVG_DBP  \
# 0         17755225           18  114.000000000  126.000000  86.000000
# 1         13039387           18   77.000000000  141.250000  74.500000
# 2         14241431           18   85.666666667  124.000000  76.333333
# 3         14332783           18   74.000000000  103.500000  62.250000
# 4         13898871           18   90.037037037  112.629630  75.925926
# ...            ...          ...            ...         ...        ...
# 119352    10582595           91  113.428571429  160.000000  76.000000
# 119353    18975602           91   87.400000000  130.222222  64.666667
# 119354    15056066           91   94.750000000  152.000000  75.250000
# 119355    12426170           91   74.000000000  123.400000  51.800000
# 119356    16100048           91   83.375000000  127.250000  67.875000
#
#             AVG_O2SAT               atime               dtime  inptdeath  \
# ...

# %% [markdown]
# ## Show descriptive statistics using describe()
# Use the ```pandas DataFrame.describe()```
# [method](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.describe.html)
# to generate descriptive statistics. Descriptive statistics include those that
# summarize the central tendency, dispersion and shape of a dataset’s
# distribution, excluding ```NaN``` values. You may also use other Python methods
# to interact with your data.

# %%
results.describe()
# Out:
#             subject_id  AGE_patient        AVG_SBP        AVG_DBP  inptdeath
# count         119357.0     119357.0  118825.000000  118825.000000   119357.0
# mean   15013355.599244    54.879974     128.253461      74.471090   0.039646
# std     2888151.019781    20.220418      17.299130      93.537499   0.195126
# min         10000032.0         18.0      10.000000       6.000000        0.0
# 25%         12502529.0         38.0     116.076923      65.777778        0.0
# 50%         15026826.0         56.0     126.800000      72.666667        0.0
# 75%         17521183.0         71.0     138.666667      80.000000        0.0
# max         19999987.0         91.0     293.000000   26028.500000        1.0

# %%
import pandas as pd

# %%
results.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119357 entries, 0 to 119356
# Data columns (total 10 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   subject_id     119357 non-null  Int64
#  1   AGE_patient    119357 non-null  Int64
#  2   AVG_HR         118846 non-null  object
#  3   AVG_SBP        118825 non-null  float64
#  4   AVG_DBP        118825 non-null  float64
#  5   AVG_O2SAT      117452 non-null  object
#  6   atime          119357 non-null  datetime64[ns]
#  7   dtime          119357 non-null  datetime64[ns]
#  8   inptdeath      119357 non-null  Int64
#  9   Date_of_Death  17676 non-null   dbdate
# dtypes: Int64(3), datetime64[ns](2), dbdate(1), float64(2), object(2)
# memory usage: 9.4+ MB

# %%
## need to convert AVG_HR and AVG_02SAT to numeric

# %%
results['AVG_HR'] = pd.to_numeric(results['AVG_HR'])

# %%
results['AVG_O2SAT'] = pd.to_numeric(results['AVG_O2SAT'])

# %%
## create new variable 'pulse pressure', 'Max_HR', 'Est_VO2_Max'

# %%
results['Pulse_Pressure'] = ((2*results['AVG_SBP'])+(results['AVG_DBP']))/3

# %%
results['Max_HR'] = (208-(results['AGE_patient']/3))

# %%
results['Est_v02_Max'] = (results['Max_HR']-results['AVG_HR'])*15.3

# %%
results['Length_of_Stay'] = ((results['dtime']) - (results['atime']))

# %%
## Also need to create new variables Length_Of_Stay (Discharege Time - Admission Time) .. and new variable  time to out patient death since discharge from hospital

# %%
results['Date_of_Death'] = pd.to_datetime(results['Date_of_Death'])

# %%
results['Time_to_OutPtDeath'] = ((results['Date_of_Death']) - (results['dtime']))

# %%
results.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119357 entries, 0 to 119356
# Data columns (total 15 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   subject_id          119357 non-null  Int64
#  1   AGE_patient         119357 non-null  Int64
#  2   AVG_HR              118846 non-null  float64
#  3   AVG_SBP             118825 non-null  float64
#  4   AVG_DBP             118825 non-null  float64
#  5   AVG_O2SAT           117452 non-null  float64
#  6   atime               119357 non-null  datetime64[ns]
#  7   dtime               119357 non-null  datetime64[ns]
#  8   inptdeath           119357 non-null  Int64
#  9   Date_of_Death       17676 non-null   datetime64[ns]
#  10  Pulse_Pressure      118825 non-null  float64
#  11  Max_HR              119357 non-null  Float64
#  12  Est_v02_Max         119357 non-null  Float64
#  13  Length_of_Stay      119357 non-null  timedelta64[ns]
# ...

# %%
results.head(8)
# Out:
#    subject_id  AGE_patient      AVG_HR     AVG_SBP    AVG_DBP   AVG_O2SAT  \
# 0    17755225           18  114.000000  126.000000  86.000000  100.000000
# 1    13039387           18   77.000000  141.250000  74.500000   98.250000
# 2    14241431           18   85.666667  124.000000  76.333333   99.000000
# 3    14332783           18   74.000000  103.500000  62.250000  100.000000
# 4    13898871           18   90.037037  112.629630  75.925926   98.925926
# 5    19531581           18   95.000000  118.600000  80.200000   99.600000
# 6    12753584           18   95.230769  123.307692  68.846154   99.538462
# 7    17312526           18   71.117647  118.941176  65.176471   99.294118
#
#                 atime               dtime  inptdeath Date_of_Death  \
# 0 2154-02-23 17:24:00 2154-03-02 16:10:00          0    2154-10-16
# 1 2138-12-25 23:39:00 2138-12-28 11:30:00          0    2139-08-17
# 2 2117-04-16 01:48:00 2117-04-16 06:36:00          0    2118-01-02
# ...
